# %% [markdown]
# This notebook provides an overview of you can use CEBRA:
# - in different modes
# - across different sessions/animals
# - across different modalities.
#
# These examples can also be found on the demos they provide on their webpage.

# %%
! pip install --pre 'cebra[datasets,demos]'
# Out:
# Requirement already satisfied: cebra[datasets,demos] in ./cebraenv/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: joblib in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (1.4.2)
# Requirement already satisfied: literate-dataclasses in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (0.0.6)
# Requirement already satisfied: scikit-learn in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (1.4.2)
# Requirement already satisfied: scipy in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (1.13.0)
# Requirement already satisfied: torch in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (2.2.2)
# Requirement already satisfied: tqdm in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (4.66.4)
# Requirement already satisfied: matplotlib in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (3.8.4)
# Requirement already satisfied: requests in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (2.31.0)
# Requirement already satisfied: ipykernel in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (6.29.4)
# Requirement already satisfied: jupyter in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (1.0.0)
# Requirement already satisfied: nbconvert in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (7.16.4)
# Requirement already satisfied: seaborn in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (0.13.2)
# Requirement already satisfied: h5py in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (3.11.0)
# Requirement already satisfied: pandas in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (1.3.4)
# Requirement already satisfied: nlb-tools in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (0.0.3)
# Requirement already satisfied: hdf5storage in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (0.1.19)
# Requirement already satisfied: openpyxl in ./cebraenv/lib/python3.9/site-packages (from cebra[datasets,demos]) (3.1.2)
# Requirement already satisfied: numpy>=1.17.3 in ./cebraenv/lib/python3.9/site-packages (from h5py->cebra[datasets,demos]) (1.26.4)
# Requirement already satisfied: appnope in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (1.6.0)
# Requirement already satisfied: packaging in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (24.0)
# Requirement already satisfied: psutil in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./cebraenv/lib/python3.9/site-packages (from ipykernel->cebra[datasets,demos]) (5.14.3)
# Requirement already satisfied: notebook in ./cebraenv/lib/python3.9/site-packages (from jupyter->cebra[datasets,demos]) (7.1.3)
# Requirement already satisfied: qtconsole in ./cebraenv/lib/python3.9/site-packages (from jupyter->cebra[datasets,demos]) (5.5.1)
# Requirement already satisfied: jupyter-console in ./cebraenv/lib/python3.9/site-packages (from jupyter->cebra[datasets,demos]) (6.6.3)
# Requirement already satisfied: ipywidgets in ./cebraenv/lib/python3.9/site-packages (from jupyter->cebra[datasets,demos]) (8.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./cebraenv/lib/python3.9/site-packages (from matplotlib->cebra[datasets,demos]) (6.4.0)
# Requirement already satisfied: beautifulsoup4 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (6.1.0)
# Requirement already satisfied: defusedxml in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (7.1.0)
# Requirement already satisfied: jinja2>=3.0 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (2.17.2)
# Requirement already satisfied: tinycss2 in ./cebraenv/lib/python3.9/site-packages (from nbconvert->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: pynwb in ./cebraenv/lib/python3.9/site-packages (from nlb-tools->cebra[datasets,demos]) (2.7.0)
# Requirement already satisfied: pytz>=2017.3 in ./cebraenv/lib/python3.9/site-packages (from pandas->cebra[datasets,demos]) (2024.1)
# Requirement already satisfied: et-xmlfile in ./cebraenv/lib/python3.9/site-packages (from openpyxl->cebra[datasets,demos]) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./cebraenv/lib/python3.9/site-packages (from requests->cebra[datasets,demos]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./cebraenv/lib/python3.9/site-packages (from requests->cebra[datasets,demos]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./cebraenv/lib/python3.9/site-packages (from requests->cebra[datasets,demos]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in ./cebraenv/lib/python3.9/site-packages (from requests->cebra[datasets,demos]) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./cebraenv/lib/python3.9/site-packages (from scikit-learn->cebra[datasets,demos]) (3.5.0)
# Requirement already satisfied: filelock in ./cebraenv/lib/python3.9/site-packages (from torch->cebra[datasets,demos]) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./cebraenv/lib/python3.9/site-packages (from torch->cebra[datasets,demos]) (4.11.0)
# Requirement already satisfied: sympy in ./cebraenv/lib/python3.9/site-packages (from torch->cebra[datasets,demos]) (1.12)
# Requirement already satisfied: networkx in ./cebraenv/lib/python3.9/site-packages (from torch->cebra[datasets,demos]) (3.2.1)
# Requirement already satisfied: fsspec in ./cebraenv/lib/python3.9/site-packages (from torch->cebra[datasets,demos]) (2024.3.1)
# Requirement already satisfied: six>=1.9.0 in ./cebraenv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->cebra[datasets,demos]) (1.16.0)
# Requirement already satisfied: webencodings in ./cebraenv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->cebra[datasets,demos]) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in ./cebraenv/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->cebra[datasets,demos]) (3.18.1)
# Requirement already satisfied: decorator in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (3.0.43)
# Requirement already satisfied: stack-data in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.6.3)
# Requirement already satisfied: exceptiongroup in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in ./cebraenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in ./cebraenv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->cebra[datasets,demos]) (4.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in ./cebraenv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->cebra[datasets,demos]) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in ./cebraenv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->cebra[datasets,demos]) (4.22.0)
# Requirement already satisfied: soupsieve>1.2 in ./cebraenv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->cebra[datasets,demos]) (2.5)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in ./cebraenv/lib/python3.9/site-packages (from ipywidgets->jupyter->cebra[datasets,demos]) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in ./cebraenv/lib/python3.9/site-packages (from ipywidgets->jupyter->cebra[datasets,demos]) (3.0.10)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./cebraenv/lib/python3.9/site-packages (from notebook->jupyter->cebra[datasets,demos]) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./cebraenv/lib/python3.9/site-packages (from notebook->jupyter->cebra[datasets,demos]) (2.27.1)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in ./cebraenv/lib/python3.9/site-packages (from notebook->jupyter->cebra[datasets,demos]) (4.1.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./cebraenv/lib/python3.9/site-packages (from notebook->jupyter->cebra[datasets,demos]) (0.2.4)
# Requirement already satisfied: hdmf>=3.12.2 in ./cebraenv/lib/python3.9/site-packages (from pynwb->nlb-tools->cebra[datasets,demos]) (3.13.0)
# Requirement already satisfied: qtpy>=2.4.0 in ./cebraenv/lib/python3.9/site-packages (from qtconsole->jupyter->cebra[datasets,demos]) (2.4.1)
# Requirement already satisfied: mpmath>=0.19 in ./cebraenv/lib/python3.9/site-packages (from sympy->torch->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: ruamel-yaml>=0.16 in ./cebraenv/lib/python3.9/site-packages (from hdmf>=3.12.2->pynwb->nlb-tools->cebra[datasets,demos]) (0.18.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./cebraenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in ./cebraenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./cebraenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./cebraenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./cebraenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (0.18.0)
# Requirement already satisfied: anyio>=3.1.0 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (4.3.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./cebraenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (2.0.1)
# Requirement already satisfied: babel>=2.10 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->cebra[datasets,demos]) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./cebraenv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->cebra[datasets,demos]) (0.9.25)
# Requirement already satisfied: ptyprocess>=0.5 in ./cebraenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.7.0)
# Requirement already satisfied: wcwidth in ./cebraenv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in ./cebraenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./cebraenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (2.4.1)
# Requirement already satisfied: pure-eval in ./cebraenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./cebraenv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./cebraenv/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (21.2.0)
# Requirement already satisfied: httpcore==1.* in ./cebraenv/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./cebraenv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->cebra[datasets,demos]) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./cebraenv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in ./cebraenv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (6.0.1)
# Requirement already satisfied: rfc3339-validator in ./cebraenv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./cebraenv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (0.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./cebraenv/lib/python3.9/site-packages (from ruamel-yaml>=0.16->hdmf>=3.12.2->pynwb->nlb-tools->cebra[datasets,demos]) (0.2.8)
# Requirement already satisfied: fqdn in ./cebraenv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.5.1)
# Requirement already satisfied: isoduration in ./cebraenv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./cebraenv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (2.4)
# Requirement already satisfied: uri-template in ./cebraenv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in ./cebraenv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in ./cebraenv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.16.0)
# Requirement already satisfied: pycparser in ./cebraenv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in ./cebraenv/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./cebraenv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos]) (2.9.0.20240316)

# %%
import sys
import os # my addtion

import numpy as np
import itertools
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import solve_ivp
import cebra.data
import torch
import cebra.integrations
import cebra.datasets
from cebra import CEBRA
import torch
import pickle

from matplotlib.collections import LineCollection
import pandas as pd

# %% [markdown]
# Let's load the data that we'll be using first.

# %%
hippocampus_a = cebra.datasets.init('rat-hippocampus-single-achilles')
hippocampus_b = cebra.datasets.init('rat-hippocampus-single-buddy')
hippocampus_c = cebra.datasets.init('rat-hippocampus-single-cicero')
hippocampus_g = cebra.datasets.init('rat-hippocampus-single-gatsby')
# Out:
# 100%|██████████| 2.68M/2.68M [00:01<00:00, 1.40MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/buddy.jl'
# 100%|██████████| 22.0M/22.0M [00:18<00:00, 1.17MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/cicero.jl'
# 100%|██████████| 9.40M/9.40M [00:04<00:00, 2.00MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/gatsby.jl'

# %%
hippocampus_pos = cebra.datasets.init('rat-hippocampus-single-achilles')

# %%
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

# %% [markdown]
# # A. Different Modes
#
# CEBRA has 3 different modes: CEBRA-Time(Discovery Mode), CEBRA-Behaviour (Hypothesis Mode) and CEBRA-Hybrid that's a cross between the two.
#
# ## 1. CEBRA Time

# %% [markdown]
# We start by building the CEBRA-Time model. This type of model is only trained on neural data and produces an embedding based on the existing temporal structure of the input data i.e. points that are close together in time in the input will also be close together on the embedding produced.

# %%
max_iterations = 2000

# %%
# build the model
cebra_time_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1.12,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

# %%
# Train on neural data only
cebra_time_model.fit(hippocampus_pos.neural)
# Out:
# pos: -0.8180 neg:  6.3799 total:  5.5619 temperature:  1.1200: 100%|██████████| 2000/2000 [00:53<00:00, 37.70it/s]
# CEBRA(batch_size=512, conditional='time', max_iterations=2000,
#       model_architecture='offset10-model', output_dimension=3, temperature=1.12,
#       time_offsets=10, verbose=True)

# %%
# Then transform the input to produce the embedding
cebra_time_embedding = cebra_time_model.transform(hippocampus_pos.neural)

# %% [markdown]
# ## 2. CEBRA Behaviour

# %%
# build the model
cebra_behavior_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

# %% [markdown]
# Here, we change the conditional to be 'time-delta' to allow the algorithm to use the behavioural variable(s) in the construction of the latent space.

# %%
# train the model using both neural data and behavioural label(s)
cebra_behavior_model.fit(hippocampus_pos.neural, hippocampus_pos.continuous_index.numpy())
# Out:
# pos: -0.8787 neg:  6.4172 total:  5.5385 temperature:  1.0000: 100%|██████████| 2000/2000 [00:54<00:00, 36.52it/s]
# CEBRA(batch_size=512, conditional='time_delta', max_iterations=2000,
#       model_architecture='offset10-model', output_dimension=3, temperature=1,
#       time_offsets=10, verbose=True)

# %%
# then transform the input to produce an embedding - 
cebra_behavior_embedding = cebra_behavior_model.transform(hippocampus_pos.neural)

# %% [markdown]
# note that we only transform the neural data (the behavioural labels are only used in training -- for both the CEBRA-Behaviour and CEBRA-hybrid).

# %% [markdown]
# ## 3. CEBRA - Hybrid

# %%
# build the model
cebra_hybrid_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10,
                        hybrid = True)

# %% [markdown]
# Notice that this model parameters look very similar to the CEBRA-Behaviour ones. The only difference is that here we set the 'hybrid' parameter to 'True'.

# %%
# train the model using both neural data and the behavioural label(s)
cebra_hybrid_model.fit(hippocampus_pos.neural, hippocampus_pos.continuous_index.numpy())
# Out:
# behavior_pos: -0.8974 behavior_neg:  6.4239 behavior_total:  5.5266 time_pos: -0.9091 time_neg:  6.4239 time_total:  5.5148: 100%|██████████| 2000/2000 [01:30<00:00, 21.98it/s]
# CEBRA(batch_size=512, conditional='time_delta', hybrid=True,
#       max_iterations=2000, model_architecture='offset10-model',
#       output_dimension=3, temperature=1, time_offsets=10, verbose=True)

# %%
# transform the input to obtain the embedding
cebra_hybrid_embedding = cebra_hybrid_model.transform(hippocampus_pos.neural)

# %% [markdown]
# Now let's visualise the embeddings

# %%
right = hippocampus_pos.continuous_index[:,1] == 1
left = hippocampus_pos.continuous_index[:,2] == 1

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,2))

ax1 = plt.subplot(141, projection='3d')
ax2 = plt.subplot(142, projection='3d')
ax3 = plt.subplot(143, projection='3d')

for dir, cmap in zip([right, left], ["cool", "viridis"]):
    ax1=cebra.plot_embedding(ax=ax1, embedding=cebra_behavior_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Behavior', cmap=cmap)
    ax2=cebra.plot_embedding(ax=ax2, embedding=cebra_time_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Time', cmap=cmap)
    ax3=cebra.plot_embedding(ax=ax3, embedding=cebra_hybrid_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Hybrid', cmap=cmap)

plt.show()

# %% [markdown]
# # B. Using CEBRA across sessions/animals
#
# We will use CEBRA-Behaviour for this, and the data will be from rats performing the same task as before: running back and forth on a linear track (recordings from the hippocampus).

# %%
# Load the data first
names = ["achilles", "buddy", "cicero", "gatsby"]
datas = [hippocampus_a.neural.numpy(), hippocampus_b.neural.numpy(), hippocampus_c.neural.numpy(), hippocampus_g.neural.numpy()]
labels = [hippocampus_a.continuous_index.numpy(), hippocampus_b.continuous_index.numpy(), hippocampus_c.continuous_index.numpy(), hippocampus_g.continuous_index.numpy()]

# %% [markdown]
# ### Single-session training
#
# Here we train each model only on one set of data. But, we 'align' the datasets to the first one, i.e. we make sure if they had different sizes or number of features* (confirm).

# %%
# single session
embeddings = dict()

# Single session training
for name, X, y in zip(names, datas, labels):
    # Fit one CEBRA model per session (i.e., per rat)
    print(f"Fitting CEBRA for {name}")
    cebra_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

    cebra_model.fit(X, y)
    embeddings[name] = cebra_model.transform(X)


# Align the single session embeddings to the first rat
alignment = cebra.data.helper.OrthogonalProcrustesAlignment()
first_rat = list(embeddings.keys())[0]

for j, rat_name in enumerate(list(embeddings.keys())[1:]):
    embeddings[f"{rat_name}"] = alignment.fit_transform(
        embeddings[first_rat], embeddings[rat_name], labels[0], labels[j+1])


# Save embeddings in current folder
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)
# Out:
# Fitting CEBRA for achilles
# pos: -0.8843 neg:  6.4161 total:  5.5319 temperature:  1.0000: 100%|██████████| 2000/2000 [00:53<00:00, 37.56it/s]
# Fitting CEBRA for buddy
# pos: -0.6661 neg:  6.4614 total:  5.7952 temperature:  1.0000: 100%|██████████| 2000/2000 [00:51<00:00, 38.50it/s]
# Fitting CEBRA for cicero
# pos: -0.5442 neg:  6.4768 total:  5.9327 temperature:  1.0000: 100%|██████████| 2000/2000 [00:53<00:00, 37.28it/s]
# Fitting CEBRA for gatsby
# pos: -0.6988 neg:  6.4560 total:  5.7572 temperature:  1.0000: 100%|██████████| 2000/2000 [00:53<00:00, 37.51it/s]

# %% [markdown]
# ### Multisession training
# Here, we train one model on all the sessions and then transform the individual datasets to get individual embeddings for the different animals.

# %%
multi_embeddings = dict()

# Multisession training
multi_cebra_model = CEBRA(model_architecture='offset10-model',
                    batch_size=512,
                    learning_rate=3e-4,
                    temperature=1,
                    output_dimension=3,
                    max_iterations=max_iterations,
                    distance='cosine',
                    conditional='time_delta',
                    device='cuda_if_available',
                    verbose=True,
                    time_offsets=10)

# Provide a list of data, i.e. datas = [data_a, data_b, ...]
multi_cebra_model.fit(datas, labels)

# Transform each session with the right model, by providing the corresponding session ID
for i, (name, X) in enumerate(zip(names, datas)):
    multi_embeddings[name] = multi_cebra_model.transform(X, session_id=i)

# Save embeddings in current folder
with open('multi_embeddings.pkl', 'wb') as f:
    pickle.dump(multi_embeddings, f)
# Out:
# pos: -0.6883 neg:  7.8089 total:  7.1206 temperature:  1.0000: 100%|██████████| 2000/2000 [08:12<00:00,  4.06it/s]

# %% [markdown]
# ### Compare embeddings
#
# Now we compare the single-session and multi-sessions embeddings.

# %%
with open('embeddings.pkl', 'rb') as f:
    embeddings = pickle.load(f)
with open('multi_embeddings.pkl', 'rb') as f:
    multi_embeddings = pickle.load(f)

# %%
def plot_hippocampus(ax, embedding, label, gray = False, idx_order = (0,1,2)):
    r_ind = label[:,1] == 1
    l_ind = label[:,2] == 1

    if not gray:
        r_cmap = 'cool'
        l_cmap = 'viridis'
        r_c = label[r_ind, 0]
        l_c = label[l_ind, 0]
    else:
        r_cmap = None
        l_cmap = None
        r_c = 'gray'
        l_c = 'gray'

    idx1, idx2, idx3 = idx_order
    r=ax.scatter(embedding [r_ind,idx1],
               embedding [r_ind,idx2],
               embedding [r_ind,idx3],
               c=r_c,
               cmap=r_cmap, s=0.05, alpha=0.75)
    l=ax.scatter(embedding [l_ind,idx1],
               embedding [l_ind,idx2],
               embedding [l_ind,idx3],
               c=l_c,
               cmap=l_cmap, s=0.05, alpha=0.75)

    ax.grid(False)
    ax.xaxis.pane.fill = False
    ax.yaxis.pane.fill = False
    ax.zaxis.pane.fill = False
    ax.xaxis.pane.set_edgecolor('w')
    ax.yaxis.pane.set_edgecolor('w')
    ax.zaxis.pane.set_edgecolor('w')

    return ax

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(241, projection='3d')
ax2 = plt.subplot(242, projection='3d')
ax3 = plt.subplot(243, projection='3d')
ax4 = plt.subplot(244, projection='3d')
axs = [ax1, ax2, ax3, ax4]

ax5 = plt.subplot(245, projection='3d')
ax6 = plt.subplot(246, projection='3d')
ax7 = plt.subplot(247, projection='3d')
ax8 = plt.subplot(248, projection='3d')
axs_multi = [ax5, ax6, ax7, ax8]

for name, label, ax, ax_multi in zip(names, labels, axs, axs_multi):
    ax = plot_hippocampus(ax, embeddings[name], label)
    ax.set_title(f'Single-{name}', y=1, pad=-20)
    ax.axis('off')
    ax_multi = plot_hippocampus(ax_multi, multi_embeddings[name], label)
    ax_multi.set_title(f'Multi-{name}', y=1, pad=-20)
    ax_multi.axis('off')


plt.subplots_adjust(wspace=0,
                    hspace=0)
plt.show()

# %% [markdown]
# You can verify that these embeddings are indeed consistent by running the 'cebra.sklearn.metrics.consistency_score' function and plotting the consistency scores as shown in the demo notebook on ' Training models across animals'.

# %% [markdown]
# # C. Using CEBRA across modalities
#
# Here, we show a brief example of how you can combine NP and Ca imaging datasets to train a model and then produce consistent embeddings for the individual datasets. For a more detailed overview, visit the CEBRA website and check out the notebook 'Decoding movie features from (V1) visual cortex'.

# %% [markdown]
# ### Load data

# %%
cortex = 'VISp'
seed=333
num_neurons = 800

ca_train = cebra.datasets.init(f'allen-movie-one-ca-{cortex}-{num_neurons}-train-10-{seed}')
np_train = cebra.datasets.init(f'allen-movie-one-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')
joint_train = cebra.datasets.init(f'allen-movie-one-ca-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')

ca_test = cebra.datasets.init(f'allen-movie-one-ca-{cortex}-{num_neurons}-test-10-{seed}')
np_test = cebra.datasets.init(f'allen-movie-one-neuropixel-{cortex}-{num_neurons}-test-10-{seed}')
joint_test = cebra.datasets.init(f'allen-movie-one-ca-neuropixel-{cortex}-{num_neurons}-test-10-{seed}')

# %%
# helper functions

def multi_session_solver(data_loader, **kwargs):
    norm = True
    if kwargs['distance'] == 'euclidean':
        norm = False
    for dataset in data_loader.dataset.iter_sessions():
        dataset.to(kwargs['device'])

    model = torch.nn.ModuleList([
        cebra.models.init(m, dataset.input_dimension,
                          kwargs['num_hidden_units'], kwargs['output_dimension'], norm)
        for dataset, m in zip(data_loader.dataset.iter_sessions(), kwargs['model_architecture'])
    ]).to(kwargs['device'])

    for m in model:
        m.to(kwargs['device'])
    for n, dataset in enumerate(data_loader.dataset.iter_sessions()):
        dataset.configure_for(model[n])
    if kwargs['distance'] == 'euclidean':
        criterion = cebra.models.InfoMSE(temperature=kwargs['temperature'])
    elif kwargs['distance'] == 'cosine':
        criterion = cebra.models.InfoNCE(temperature=kwargs['temperature'])
    optimizer = torch.optim.Adam(itertools.chain(model.parameters(), criterion.parameters()), lr=kwargs['learning_rate'])
    return cebra.solver.MultiSessionSolver(model=model,
                                           criterion=criterion,
                                           optimizer=optimizer,
                                           tqdm_on=kwargs['verbose'])


@torch.no_grad()
def get_emissions(model, dataset):
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    model.to(device)
    dataset.configure_for(model)
    return model(dataset[torch.arange(len(dataset))].to(device)).cpu().numpy()

def _compute_emissions_single(solver, dataset):
    return get_emissions(solver.model, dataset)

def _compute_emissions_multi(solver, dataset):

    return {
        i :
            get_emissions(model, session)
            for i, (model, session) in enumerate(zip(solver.model, dataset.iter_sessions()))
    }

# %%
train_steps = 10000

# %%
joint_loader = cebra.data.ContinuousMultiSessionDataLoader(joint_train, num_steps = train_steps, batch_size = 512, conditional = 'time_delta', time_offset=1)

# %%
cebra_joint = multi_session_solver(data_loader = joint_loader, model_architecture = ['offset1-model', 'resample1-model'],
                 distance = 'cosine', num_hidden_units = 128, output_dimension = 128,
                verbose = True, device = DEVICE, temperature = 1, learning_rate = 3e-4)

# %%
cebra_joint.fit(joint_loader)
cebra_joint_embs = _compute_emissions_multi(cebra_joint, joint_train)
# Out:
# pos: -0.9959 neg:  6.9943 total:  5.9983 temperature:  1.0000:  47%|████▋     | 4707/10000 [25:32<28:42,  3.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/brian.gitahi/Desktop/AIND/CEBRA/Git/CEBRA/Basics.ipynb Cell 46 line 1
# ----> <a href='vscode-notebook-cell:/Users/brian.gitahi/Desktop/AIND/CEBRA/Git/CEBRA/Basics.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> cebra_joint.fit(joint_loader)
#       <a href='vscode-notebook-cell:/Users/brian.gitahi/Desktop/AIND/CEBRA/Git/CEBRA/Basics.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a> cebra_joint_embs = _compute_emissions_multi(cebra_joint, joint_train)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/cebra/solver/base.py:194, in Solver.fit(self, loader, valid_loader, save_frequency, valid_frequency, decode, logdir, save_hook)
#     192 self.model.train()
#     193 for num_steps, batch in iterator:
# --> 194     stats = self.step(batch)
#     195     iterator.set_description(stats)
#     197     if save_frequency is None:
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/cebra/solver/base.py:226, in Solver.step(self, batch)
#     217 """Perform a single gradient update.
#     218
#     219 Args:
#    (...)
#     223     Dictionary containing training metrics.
#     224 """
#     225 self.optimizer.zero_grad()
# --> 226 prediction = self._inference(batch)
#     227 loss, align, uniform = self.criterion(prediction.reference,
#     228                                       prediction.positive,
#     229                                       prediction.negative)
#     231 loss.backward()
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/cebra/solver/multi_session.py:103, in MultiSessionSolver._inference(self, batches)
#     101     batch.to(self.device)
#     102     refs.append(model(batch.reference))
# --> 103     poss.append(model(batch.positive))
#     104     negs.append(model(batch.negative))
#     105 ref = torch.stack(refs, dim=0)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/cebra/models/model.py:240, in _OffsetModel.forward(self, inp)
#     228 def forward(self, inp):
#     229     """Compute the embedding given the input signal.
#     230
#     231     Args:
#    (...)
#     238     is normalized to the hypersphere (`normalize = True`).
#     239     """
# --> 240     return self.net(inp)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/cebra/models/layers.py:97, in _MeanAndConv.forward(self, inp)
#      96 def forward(self, inp: torch.Tensor) -> torch.Tensor:
# ---> 97     connect = self.layer(inp)
#      98     downsampled = F.interpolate(inp, scale_factor=1 / self.downsample)
#      99     return torch.cat([connect, downsampled[..., :connect.size(-1)]], dim=1)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/conv.py:310, in Conv1d.forward(self, input)
#     309 def forward(self, input: Tensor) -> Tensor:
# --> 310     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Desktop/AIND/CEBRA/Git/CEBRA/cebraenv/lib/python3.9/site-packages/torch/nn/modules/conv.py:306, in Conv1d._conv_forward(self, input, weight, bias)
#     302 if self.padding_mode != 'zeros':
#     303     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     304                     weight, bias, self.stride,
#     305                     _single(0), self.dilation, self.groups)
# --> 306 return F.conv1d(input, weight, bias, self.stride,
#     307                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize = (12,5))

ax1 = plt.subplot(121)
ax1.set_title('Ca, jointly trained')
ax1.scatter(cebra_joint_embs[0][:,0], cebra_joint_embs[0][:,1], cmap = 'magma', c = np.tile(np.arange(900),9), s=1)
ax1.axis('off')

ax2 = plt.subplot(122)
ax2.set_title('Neuropixel, jointly trained')
ax2.scatter(cebra_joint_embs[1][:,0], cebra_joint_embs[1][:,1], cmap = 'magma', c = np.tile(np.repeat(np.arange(900),4),9), s=1)
ax2.axis('off')
